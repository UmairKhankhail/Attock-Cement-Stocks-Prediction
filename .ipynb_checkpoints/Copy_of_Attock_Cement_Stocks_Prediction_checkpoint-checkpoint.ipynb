# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime

# %%
dataset=pd.read_csv("ATOC Historical Data.csv",index_col='Date',parse_dates=True)

# %%
dataset.head()
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2021-10-08  133.51  134.50  131.00  132.00  33.20K
# 2021-10-07  131.50  137.00  131.50  136.14  44.70K
# 2021-10-06  134.00  134.70  128.00  128.50  26.90K
# 2021-10-05  137.11  137.11  135.00  136.04  11.70K
# 2021-10-04  139.99  140.00  139.65  139.88   2.20K

# %%
dataset.isna().any()
# Out:
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2021-11-12 to 2017-10-12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1006 non-null   float64
#  1   High    1006 non-null   float64
#  2   Low     1006 non-null   float64
#  3   Close   1006 non-null   float64
#  4   Volume  1006 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 47.2+ KB

# %%
dataset['Open'].plot(figsize=(16,6))

# %%
dataset['Volume']=dataset['Volume'].str.replace('K','')
dataset['Volume']=dataset['Volume'].str.replace('M','')
dataset['Volume']=dataset['Volume'].astype(float)

# %% [markdown]
# # Rolling Mean

# %%
rolling_mean=dataset.rolling(7).mean().head(20)

# %%
dataset['Open'].plot(figsize=(16,6))
dataset.rolling(window=30).mean()['Close'].plot()

# %%
dataset['Cose 30 days mean']=dataset['Close'].rolling(window=30).mean()

# %%
dataset.rename({'Cose 30 days mean':'Close 30 days mean'},axis=1,inplace=True)

# %%
dataset[['Close','Close 30 days mean']].plot(figsize=(16,6))

# %%
training_set=dataset['Open']
training_set=pd.DataFrame(training_set)
training_set.head()
# Out:
#               Open
# Date
# 2021-11-12  130.00
# 2021-11-11  134.00
# 2021-11-10  132.00
# 2021-11-09  137.11
# 2021-11-08  138.17

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
training_set_scaled=sc.fit_transform(training_set)
training_set_scaled
# Out:
# array([[0.52027187],
#        [0.55188493],
#        [0.5360784 ],
#        ...,
#        [0.63550146],
#        [0.6651387 ],
#        [0.77712795]])

# %%
# 60 days for 1 output i.e output on every 60th day
x_train=[]
y_train=[]
for i in range(60,len(training_set)):
    x_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
x_train=np.array(x_train)
y_trian=np.array(y_train)

# %%
x_train.shape
# Out:
# (946, 60)

# %%
# reshaping the data, to convert the data into 3 dimension
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (946, 60, 1)

# %%
# Building the RNN Model

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor= Sequential()

# %% [markdown]
# ## Training the model

# %%
# input layer
regressor.add(LSTM(units=50,return_sequences=True,input_shape=(x_train.shape[1],1)))
regressor.add(Dropout(0.2)) 
# droupout is regularization technique for reducing overitting the model

regressor.add(LSTM(units=50,return_sequences=True))
regressor.add(Dropout(0.2))
              
regressor.add(LSTM(units=50,return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units=1))

# %%
# compiling RNN
regressor.compile(optimizer='adam', loss="mean_squared_error")

# fiting RNN to training set
train_x = np.asarray(x_train)
train_y = np.asarray(y_train)
regressor.fit(train_x,train_y,epochs=100,batch_size=32)
# epochs---> frame of time
# batch_size=32 --> no. of training examples utilized in one iteration
# Out:
# Epoch 1/100
# 30/30 [==============================] - 11s 124ms/step - loss: 0.0513
# Epoch 2/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0113
# Epoch 3/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0104
# Epoch 4/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0093
# Epoch 5/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0101
# Epoch 6/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0088
# Epoch 7/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0084
# Epoch 8/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0083
# Epoch 9/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0085
# Epoch 10/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0074
# Epoch 11/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0091
# Epoch 12/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0079
# Epoch 13/100
# 30/30 [==============================] - 4s 123ms/step - loss: 0.0072
# Epoch 14/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0070
# Epoch 15/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0073
# Epoch 16/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0069
# Epoch 17/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0065
# Epoch 18/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0061
# Epoch 19/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0061
# Epoch 20/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0054
# Epoch 21/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0062
# Epoch 22/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0059
# Epoch 23/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0054
# Epoch 24/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0058
# Epoch 25/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0054
# Epoch 26/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0053
# Epoch 27/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0051
# Epoch 28/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0049
# Epoch 29/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0059
# Epoch 30/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0052
# Epoch 31/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0045
# Epoch 32/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0047
# Epoch 33/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0045
# Epoch 34/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0041
# Epoch 35/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0046
# Epoch 36/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0045
# Epoch 37/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0041
# Epoch 38/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0047
# Epoch 39/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0044
# Epoch 40/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0043
# Epoch 41/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0037
# Epoch 42/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0039
# Epoch 43/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0047
# Epoch 44/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0038
# Epoch 45/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0037
# Epoch 46/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0040
# Epoch 47/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0039
# Epoch 48/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0036
# Epoch 49/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0034
# Epoch 50/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0031
# Epoch 51/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0033
# Epoch 52/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0031
# Epoch 53/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0033
# Epoch 54/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0030
# Epoch 55/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0031
# Epoch 56/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0033
# Epoch 57/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0030
# Epoch 58/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0030
# Epoch 59/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0031
# Epoch 60/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0029
# Epoch 61/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0029
# Epoch 62/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0030
# Epoch 63/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0027
# Epoch 64/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0029
# Epoch 65/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0028
# Epoch 66/100
# 30/30 [==============================] - 4s 123ms/step - loss: 0.0029
# Epoch 67/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0030
# Epoch 68/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0030
# Epoch 69/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0031
# Epoch 70/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0030
# Epoch 71/100
# 30/30 [==============================] - 4s 122ms/step - loss: 0.0024
# Epoch 72/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0025
# Epoch 73/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0028
# Epoch 74/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0027
# Epoch 75/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0027
# Epoch 76/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0025
# Epoch 77/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0026
# Epoch 78/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0026
# Epoch 79/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0024
# Epoch 80/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0026
# Epoch 81/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0023
# Epoch 82/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0025
# Epoch 83/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0024
# Epoch 84/100
# 30/30 [==============================] - 4s 123ms/step - loss: 0.0023
# Epoch 85/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0022
# Epoch 86/100
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0023
# Epoch 87/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0021
# Epoch 88/100
# 30/30 [==============================] - 4s 122ms/step - loss: 0.0022
# Epoch 89/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0021
# Epoch 90/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0023
# Epoch 91/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0024
# Epoch 92/100
# 30/30 [==============================] - 4s 121ms/step - loss: 0.0024
# Epoch 93/100
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0021
# Epoch 94/100
# 30/30 [==============================] - 4s 126ms/step - loss: 0.0022
# Epoch 95/100
# 30/30 [==============================] - 4s 128ms/step - loss: 0.0020
# Epoch 96/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0022
# Epoch 97/100
# 30/30 [==============================] - 4s 124ms/step - loss: 0.0020
# Epoch 98/100
# 30/30 [==============================] - 4s 123ms/step - loss: 0.0020
# Epoch 99/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0022
# Epoch 100/100
# 30/30 [==============================] - 4s 125ms/step - loss: 0.0023

# %% [markdown]
# ### Prediction and Visualizations

# %%
dataset_test=pd.read_csv("test.csv",index_col='Date',parse_dates=True)

# %%
dataset_test.head()
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2021-11-12  130.00  132.90  130.00  132.90   5.80K
# 2021-11-11  134.00  134.00  130.00  130.00  55.30K
# 2021-11-10  132.00  134.00  131.40  131.99  14.60K
# 2021-11-09  137.11  137.11  131.25  131.25  65.40K
# 2021-11-08  138.17  142.00  138.00  139.75  30.20K

# %%
dataset_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2021-11-12 to 2017-10-12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1006 non-null   float64
#  1   High    1006 non-null   float64
#  2   Low     1006 non-null   float64
#  3   Close   1006 non-null   float64
#  4   Volume  1006 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 47.2+ KB

# %%
dataset_test['Volume']=dataset_test['Volume'].str.replace('K','')
dataset_test['Volume']=dataset_test['Volume'].str.replace('M','')
dataset_test['Volume']=dataset_test['Volume'].astype(float)

# %%
test_set=dataset_test['Open']
test_set=pd.DataFrame(test_set)

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2021-11-12 to 2017-10-12
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1006 non-null   float64
# dtypes: float64(1)
# memory usage: 15.7 KB

# %%
real_stock_price=dataset_test.iloc[:,1:2].values

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2021-11-12 to 2017-10-12
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1006 non-null   float64
# dtypes: float64(1)
# memory usage: 15.7 KB

# %%
complete_dataset=pd.concat((dataset['Open'],dataset_test['Open']),axis=0)
inputs=complete_dataset[len(complete_dataset)-len(dataset_test)-60:].values
inputs=inputs.reshape(-1,1)
inputs=sc.transform(inputs)

X_test=[]
for i in range(60,80):
    X_test.append(inputs[i-60:i,0])
X_test=np.array(X_test)
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_stock_price=regressor.predict(X_test)
predicted_stock_price=sc.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price=pd.DataFrame(predicted_stock_price)
predicted_stock_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     float32
# dtypes: float32(1)
# memory usage: 208.0 bytes

# %% [markdown]
# ### Visualization fo results

# %%
plt.plot(real_stock_price,color='red',label='Real Attock Stock Price')
plt.plot(predicted_stock_price,color='blue',label='Predicted Attock Stock Price')
plt.title("Attock Cement Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Attock Stock Price")
plt.legend()
plt.show()
